# %% [markdown]
# # Graph math. functions

# %%
from matplotlib import pyplot
import math
import numpy as np


x_list=np.arange(-10,10,0.1)
y_list=[]

for x in x_list:
  y=math.sin(x)
 
  y_list.append(y)


  #print(len(x_list))   
  #print(len(y_list)) 
 
  #print(f'x={x_list}, y={y_list}')
  #print(f'x={x_list[n-1]}, y={y_list[n-1]}')
    
pyplot.figure(figsize=(7,5))
pyplot.plot(x_list,y_list)
pyplot.xlabel('x')
pyplot.ylabel('y')
pyplot.show()

# %% [markdown]
# # Calculate pi by power series : 07_01_2020

# %%
# calculate PI value 3.141...

def pi_power(n):
  pi=0
  for x in range(n):
      pi=pi+4.0*(-1)**x/(2*x+1)
      
  print(f'n={x}, pi={pi}')
    
pi_power(1000000)
# Out:
# n=999999, pi=3.1415916535897743

# %% [markdown]
# # Convergence check graph of pi : 07_01_2020

# %%
from matplotlib import pyplot

x_list=[]
y_list=[]
def pi_power(n):
  pi=0
  for x in range(n):
      pi=pi+4.0*(-1)**x/(2*x+1)
      x_list.append(x)
      y_list.append(pi)
      

  #print(len(x_list))   
  #print(len(y_list)) 
 
  #print(f'x={x_list}, y={y_list}')
  print(f'x={x_list[n-1]}, y={y_list[n-1]}')
    
pi_power(100)

pyplot.plot(x_list,y_list)
pyplot.xlabel('x')
pyplot.ylabel('pi')
pyplot.show()
# Out:
# x=99, y=3.1315929035585537

# %%
from matplotlib import pyplot

x_list=[]
y_list=[]
def pi_power(n):
  pi=0
  for x in range(n):
      pi=pi+4.0*(-1)**x/(2*x+1)
      x_list.append(x)
      y_list.append(pi)
      

  #print(len(x_list))   
  #print(len(y_list)) 
 
  #print(f'x={x_list}, y={y_list}')
  print(f'x={x_list[n-1]}, y={y_list[n-1]}')
    
pi_power(1000)

pyplot.plot(x_list,y_list)
pyplot.xlabel('x')
pyplot.ylabel('pi')
pyplot.show()
# Out:
# x=999, y=3.140592653839794

# %%
from matplotlib import pyplot

x_list=[]
y_list=[]
def pi_power(n):
  pi=0
  for x in range(n):
      pi=pi+4.0*(-1)**x/(2*x+1)
      x_list.append(x)
      y_list.append(pi)
      

  #print(len(x_list))   
  #print(len(y_list)) 
 
  #print(f'x={x_list}, y={y_list}')
  print(f'x={x_list[n-1]}, y={y_list[n-1]}')
    
pi_power(10000000)

pyplot.plot(x_list,y_list)
pyplot.xlabel('x')
pyplot.ylabel('pi')
pyplot.show()
# Out:
# x=9999999, y=3.1415925535897915

# %% [markdown]
# # Calculate e : Euler constant number e=2.17... & graph

# %%
print('Euler constant:')

# x_list=[ ]
#for i in range(10):
#  x_list=pow(10,i)*1.0
#  print(f'i={i},x_list={x_list}')

from matplotlib import pyplot
import numpy as np

e_dict = {}
e_list = []
x_list = []
y_list = []
xe_list = []
for j in range(12):
   x=pow(10,j)
   e= pow(1+1/x , x)
    
   x_list.append(x)
   y_list.append(e)
    
   e_dict[x] = e
   #print(f'x= {x}')
   #print(f'e= {e}')
print(e_dict)

# change dictionary to list
for k in e_dict.items():
   e_list.append(k)
print(e_list)

# change list to matrix array : you must import numpy above before this command
xe=np.array(e_list)
print(xe)


pyplot.plot(x_list, y_list)
pyplot.xlabel('x')
pyplot.ylabel('e')
pyplot.show()
# Out:
# Euler constant:
# {1: 2.0, 10: 2.5937424601000023, 100: 2.7048138294215285, 1000: 2.7169239322355936, 10000: 2.7181459268249255, 100000: 2.7182682371922975, 1000000: 2.7182804690957534, 10000000: 2.7182816941320818, 100000000: 2.7182817983473577, 1000000000: 2.7182820520115603, 10000000000: 2.7182820532347876, 100000000000: 2.71828205335711}
# [(1, 2.0), (10, 2.5937424601000023), (100, 2.7048138294215285), (1000, 2.7169239322355936), (10000, 2.7181459268249255), (100000, 2.7182682371922975), (1000000, 2.7182804690957534), (10000000, 2.7182816941320818), (100000000, 2.7182817983473577), (1000000000, 2.7182820520115603), (10000000000, 2.7182820532347876), (100000000000, 2.71828205335711)]
# [[1.00000000e+00 2.00000000e+00]
#  [1.00000000e+01 2.59374246e+00]
#  [1.00000000e+02 2.70481383e+00]
#  [1.00000000e+03 2.71692393e+00]
#  [1.00000000e+04 2.71814593e+00]
#  [1.00000000e+05 2.71826824e+00]
#  [1.00000000e+06 2.71828047e+00]
#  [1.00000000e+07 2.71828169e+00]
#  [1.00000000e+08 2.71828180e+00]
#  [1.00000000e+09 2.71828205e+00]
#  [1.00000000e+10 2.71828205e+00]
#  [1.00000000e+11 2.71828205e+00]]

# %% [markdown]
# # Matrix calculation

# %%
# 06_27_2020 This is a matrix calculation program to remind things learned yester days

import numpy
import numpy.linalg

# input simultaneous linear equation as a matrix

m,n=list(map(int,input('size of matrix').split(',')))
print(m,n)

AA=[[int(x) for x in input().split(',')]for y in range(m)]
bb=[int(x) for x in input('b1~bn').split(',')]
A=numpy.asmatrix(AA)
bT=numpy.asmatrix(bb)
b=bT.T
print(A)
print(b)
x=numpy.linalg.solve(A,b)
print(x)
# Out:
# size of matrix3,3
# 3 3
# -1,2, 5
# 3,2,7
# 5,-1,3
# b1~bn2,1,-5
# [[-1  2  5]
#  [ 3  2  7]
#  [ 5 -1  3]]
# [[ 2]
#  [ 1]
#  [-5]]
# [[ 0.19230769]
#  [ 3.30769231]
#  [-0.88461538]]

# %% [markdown]
# # Select 6 numbers from 1~45

# %%
#DD=[int(x) for x in input().split(',')]

DD=[919,9,14,17,18,42,44,35]
print(DD)

#N=int(input("mixing number N="))
N=15

import random
import operator
import numpy as np

num_list=[]
x_list=[]
x_bask=[]
x_bask_sort=[]
x_num={}
x_lotto={}
y_lotto=[]
keep=[]

for i in range(45):
    num_list.append(i+1)


# 45번까지 숫자중 6개 숫자를 랜덤 으로 N번 추출하여 리스트에에 담고,
for j in range(N):
  x_6=random.sample(num_list,6)
  x_list.append(x_6)
  
  for k in range(6):
    x_bask.append(x_6[k])
    
  #print(f'x_lotto_random={x_6}')
x_bask_sort=sorted(x_bask)    
#print(x_bask_sort)

# x_bask_sort 에 담긴 오름차순으로 배열된 6*N의 수를 x_num dictionary에 key(1~45 중의 수) : value(나온 회수)로 나눠 담는다
for i in x_bask_sort:
    k=0
    for j in x_bask_sort:
        if i==j:
            k=k+1
            continue
        x_num[i]=k
#print(x_num)

# key(1~45 고유수)의 오름차순으로 배열된 x_num 딕셔너리를 value 내림차순으로 재정열하여 x_lotto 리스트에 담는다
#x_lotto=sorted(x_num.items(),key=lambda item:item[1])  # dictionary acending sort by value

x_lotto=sorted(x_num.items(),key=lambda item:item[1], reverse=True) # dictionary decending sort by value

#x_lotto=sorted(x_num.items(),key=operator.itemgetter(0))
# 인자값에 있는 key=operator.itemgetter(0)는 정렬하고자 하는 키 값을 0번째 인덱스 기준으로 하겠다는 것입니다.
# 0번째 인자는 Key입니다. itemgetter(1)의 1번째 인자는 value 입니다.

# value  내림차순으로 정렬되어 있으므로 앞에서 6개까지 꺼내어 y_lotto 리스트에 담고  
# sorted 하면 key(첫번째 column)기준으로 오름차순 재배열된다
for k in range(6):
 y_lotto.append(x_lotto[k])

b=sorted(y_lotto)
print(b)

# 리스트를 np.array()로 행렬로 바꾸어 column 만 프린트합니다
bb=np.array(b)
print(bb[:,0])


b_list=list(x_num.keys())
print(len(b_list))

k=0
for i in range(45):
  ia=i+1
  if ia in b_list:
        k +=1
  else :
        keep.append(ia) 
print(k)
print(keep)
# Out:
# [919, 9, 14, 17, 18, 42, 44, 35]
# [(5, 3), (8, 4), (11, 3), (13, 6), (33, 6), (34, 4)]
# [ 5  8 11 13 33 34]
# 38
# 38
# [7, 23, 27, 28, 35, 36, 42]
